# %%
def myFun(x,y=50):
    print("x: ",x)
    print("y: ",y)
myFun(10)
# Out:
# x:  10
# y:  50

# %%
def my_function(country="Norway"):
    print("I am from "+country)
my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %%
def nameAge(name,age):
    print("Hi,I am ",name)
    print("My age is ",age)
nameAge("Suraj",27)
nameAge(27,"Suraj")
# Out:
# Hi,I am  Suraj
# My age is  27
# Hi,I am  27
# My age is  Suraj

# %%
def myFun(*argv):
    for arg in argv:
        print(arg)
myFun('Hello','Welcome','to','MIT')
# Out:
# Hello
# Welcome
# to
# MIT

# %%
#code for recursive function
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(4))
# Out:
# 24
